# %%
# Sifat logaritma log a^b = b * log a

import math
a_30 = float(input('nilai a adalah'))
b_30 = float(input('nilai b adalah'))
c_30 = math.log((-1 + 5**0.5) / 2)

print ((a_30*c_30)/(b_30*c_30))
# Out:
# nilai a adalah 7.9
# nilai b adalah 16.6
# 0.4759036144578313

# %%
import numpy as np
import math
# Sifat logaritma log a^b = b * log a

#Diketahui nilai x^2024 - x^2025 = (x(1-x))^n
x1_30 = 0.517
x2_30 = 0.692
#Cari nilai n terlebih dahulu menggunakan substitusi dengan x1
#Ubah x^2024 - x^2025 = (x(1-x))^n menjadi 2024*log(x)+log(1-x)
#Mencari nilai n menggunakkan log
g_30 = 2024*np.log(abs(x1_30)) + np.log(abs(1-x1_30))
#Sifat logaritma log(x(1-x)) menjadi log(x)+log(1-x) 
h_30 = np.log(abs(x1_30)) + np.log(abs(1-(x1_30)))
#nilai n dengan logaritma, maka n=log(x^2024-x^2025)/log(x(1-x))
n1_30= (g_30/h_30)
print("dengan menggunakan sifat logaritma, maka ")
print("nilai n adalah {}".format(n1_30))

#Cari nilai n terlebih dahulu menggunakan substitusi dengan x2
print("mencari nilai n dengan substitusi nilai x2")
x2_30 = -1.618033988749895
#Ubah x^2024 - x^2025 = (x(1-x))^n menjadi 2024*log(x)+log(1-x)
r_30 = 2024*np.log(abs(x2_30)) + np.log(abs(1-(x2_30)))
#Sifat logaritma log(x(1-x)) menjadi log(x)+log(1-x)
p_30 = np.log(abs(x2_30)) + np.log(abs(1-(x2_30)))
#nilai n dengan logaritma, maka n=log(x^2024-x^2025)/log(x(1-x))
n2_30 = (r_30/p_30)
print("dengan menggunakan sifat logaritma, maka ")
print("nilai n adalah {}".format(n2_30))
# Out:
# dengan menggunakan sifat logaritma, maka
# nilai n adalah 962.9065218031838
# mencari nilai n dengan substitusi nilai x2
# dengan menggunakan sifat logaritma, maka
# nilai n adalah 675.3333333333334
