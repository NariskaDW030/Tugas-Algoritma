# %%
nama_30 = input ("Siapakah nama kamu ?")
gender_30 = input ("Apakah kamu perempuan atau laki-laki?")
if gender_30 == str ("perempuan") :
    print ("Apakabar cantik ^-^ ")

if gender_30 == str ("laki-laki") :
    print ("Apakabar ganteng :3")
gen_30 = input ("Kamu penasaran ga sih, kamu termasuk generasi apa? (iya atau tidak)")
if gen_30 == str ("iya"):
    kelahiran_30 = float(input ("Kalau gitu, kamu lahir tahun berapa ?"))
    if kelahiran_30 > 2012 :
        print ("Wah,berati kamu generasi Post Gen Z")
    if kelahiran_30 > 1996 and kelahiran_30 <= 2012 :
        print ("Wah,berarti kamu generasi Z")
    if kelahiran_30 > 1980 and kelahiran_30 <= 1996 :
        print ("Wah,berarti kamu generasi Y")
    if kelahiran_30 >= 1965 and kelahiran_30 <=1980 :
        print ("Wah, berarti kamu generasi X ya")
    if kelahiran_30 < 1965 and kelahiran_30 >= 1946 :
        print ("Wah, berarti kamu generasi Baby Boomers ya ")
    if kelahiran_30 <1946 :
        print ("WAH, GENERASI SEPUH NIHH")
else: print ("Yaudah deh gapapa, next time")
# Out:
# Siapakah nama kamu ? nariska
# Apakah kamu perempuan atau laki-laki? perempuan
# Apakabar cantik ^-^
# Kamu penasaran ga sih, kamu termasuk generasi apa? (iya atau tidak) iya
# Kalau gitu, kamu lahir tahun berapa ? 1957
# Wah, berarti kamu generasi Baby Boomers ya

# %%
print ("Haii, masukkin data kamu yuk supaya aku ringkas ^-^")
nama_30 = input ("Siapa nama kamu ?")
umur_30 = input ("Umur kamu berapa ?")
tinggal_30 = input ("Kamu tinggal dimana ?")
nomor_HP_30 = input ("Nomor HP kamu berapa ?")
print ("Hai " + nama_30 + ", umur " + umur_30 + " tinggal di " + tinggal_30 + " dengan nomor HP " + nomor_HP_30)
print ("Senang berkenalan dengan kamu, " + nama_30)
# Out:
# Haii, masukkin data kamu yuk supaya aku ringkas ^-^
