# %%
print ("Hai, Ayo hitung berapa sisa uang mu didompet hari ini")
print ('Pertama, masukkan nama lengkap mu')
nama = input ('Nama depan')
tengah = input ('Nama tengah')
belakang = input ('Nama belakang')
uang_dompet = input ('Berapa uangmu di dompet ? (dengan angka)')
uang_keluar = input ('Berapa pengeluaran mu hari ini ? (dengan angka) ')
sisa_uang = int (uang_dompet) - int (uang_keluar)
print(f"{nama} {tengah} {belakang} ,sisa uang mu didompet adalah {str (sisa_uang)}")

# %%
print ('Mari bermain dengan huruf')
kata = input('Masukkan kata yang ingin dicoba (minimal 10 huruf)')
print (len(kata))
print (kata[:])
print (kata[1:8])
print (kata[0:10:3])
print (kata[2:-3:5])
print ('Sangat menyenangkan bukan ^-^')
# Out:
# Mari bermain dengan huruf
# Masukkan kata yang ingin dicoba (minimal 10 huruf) gita sekarini
# 13
# gita sekarini
# ita sek
# gaer
# tk
# Sangat menyenangkan bukan ^-^

# %%
huruf = 'Do you want to build a snowman ?'
print ('you' in huruf)
print ('YOU' in huruf)
print ('snowman' in huruf)
huruf.find ('want')
# Out:
# True
# False
# True
# 7

# %%
print ('Selamat datang di Megamart')
print ('Disini kamu hanya bisa membeli buah apel, pisang, dan jeruk')
apel = input('Berapa apel yang ingin kamu beli ?')
pisang = input ('Berapa pisang yang ingin kamu beli ?')
jeruk= input ('Berapa jeruk yang ingin kamu beli ?')
print ('Sekarang mari kita buktikan apakah apel > pada pisang')
print (apel>pisang)
print ('Dan apakah total perkalian dari apel dan pisang >= jeruk')
axp = (int(apel)*int(pisang))
ap_j = (int(axp) >= int(jeruk))
print (ap_j)
print ('Maka kita bisa buktikan apakah apel > pisang atau total perkalian dari apel dan pisang >= jeruk benar ?')
hasil= ((apel>pisang) or (ap_j))
print (hasil)
# Out:
# Selamat datang di Megamart
# Disini kamu hanya bisa membeli buah apel, pisang, dan jeruk
# Berapa apel yang ingin kamu beli ? 2
# Berapa pisang yang ingin kamu beli ? 3
# Berapa jeruk yang ingin kamu beli ? 5
# Sekarang mari kita buktikan apakah apel > pada pisang
# False
# Dan apakah total perkalian dari apel dan pisang >= jeruk
# True
# Maka kita bisa buktikan apakah apel > pisang atau total perkalian dari apel dan pisang >= jeruk benar ?
# True
